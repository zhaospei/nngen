# %%
import pandas as pd

file = 'cmg-data/cmg-data-processed.parquet'

df = pd.read_parquet(file, engine='fastparquet')

df.head()
# Out:
#                                   commit_id  \
# 0  d7930d7f820e5dd6b07b823f155aeb943b525e16
# 1  fc4fc1286709575df822a0b7053bde3c22922756
# 2  b979e19af7d8c21dbd0ce3368f1652bc25e22898
# 3  83bf3a9f37f4a5d3f56a727db19fb668d8482408
# 4  9213d690a8e36e359ce8314db5d0e4fe83b822dd
#
#                                                 diff  deleted  \
# 0  @@ -41,6 +41,8 @@ typedef struct {\n       XML...      100
# 1  @@ -154,8 +154,8 @@ gst_play_set_property (\tG...  157,184
# 2  @@ -459,6 +459,7 @@ start_play_tune (GstSidDec...     None
# 3  @@ -1855,7 +1855,7 @@ init_failed:\n static gb...     1857
# 4  @@ -1057,6 +1057,7 @@ gst_mpeg2dec_handle_fram...     None
#
#              added                 old_path_file  \
# 0           43,102               src/expat_erl.c
# 1  156,183,515,516  gst-libs/gst/play/play.old.c
# 2              461      ext/sidplay/gstsiddec.cc
# 3             1857    ext/mpeg2dec/gstmpeg2dec.c
# 4             1059    ext/mpeg2dec/gstmpeg2dec.c
#
# ...

# %%
len_msg = df["len_msg"]

print(len_msg.max())
# Out:
# 12

# %%
label = df["label"]
label.sort_values(ascending=False)

len_label = df["label"].str.count(' ') + 1

ls = len_label.to_list()
ls.sort(reverse=True)
print(ls)
# Out:
# [13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 1
# ...
